# %% [markdown]
# # packages in environment at C:\Users\lyk\.conda\envs\sevenpython36:
# #
# # Name                    Version                   Build  Channel
# absl-py                   0.15.0                   pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# astor                     0.8.1                    pypi_0    pypi
# astunparse                1.6.3                    pypi_0    pypi
# azure                     1.0.3                    pypi_0    pypi
# azure-common              1.1.28                   pypi_0    pypi
# azure-mgmt                0.20.2                   pypi_0    pypi
# azure-mgmt-common         0.20.0                   pypi_0    pypi
# azure-mgmt-compute        0.20.1                   pypi_0    pypi
# azure-mgmt-network        0.20.1                   pypi_0    pypi
# azure-mgmt-nspkg          3.0.2                    pypi_0    pypi
# azure-mgmt-resource       0.20.1                   pypi_0    pypi
# azure-mgmt-storage        0.20.0                   pypi_0    pypi
# azure-nspkg               3.0.2                    pypi_0    pypi
# azure-servicebus          0.20.1                   pypi_0    pypi
# azure-servicemanagement-legacy 0.20.2                   pypi_0    pypi
# azure-storage             0.20.3                   pypi_0    pypi
# backoff                   1.11.1                   pypi_0    pypi
# baselines                 0.1.3                    pypi_0    pypi
# blas                      1.0                         mkl
# cached-property           1.5.2                    pypi_0    pypi
# cachetools                4.2.4                    pypi_0    pypi
# certifi                   2021.5.30        py36haa95532_0
# charset-normalizer        2.0.12                   pypi_0    pypi
# clang                     5.0                      pypi_0    pypi
# click                     8.0.4                    pypi_0    pypi
# cloudpickle               1.6.0                    pypi_0    pypi
# colorama                  0.4.5                    pypi_0    pypi
# configparser              5.2.0                    pypi_0    pypi
# cycler                    0.11.0                   pypi_0    pypi
# dataclasses               0.8                      pypi_0    pypi
# decorator                 5.1.1                    pypi_0    pypi
# dill                      0.3.4                    pypi_0    pypi
# docker-pycreds            0.4.0                    pypi_0    pypi
# flatbuffers               1.12                     pypi_0    pypi
# gast                      0.4.0                    pypi_0    pypi
# gitdb                     4.0.9                    pypi_0    pypi
# gitpython                 3.1.18                   pypi_0    pypi
# google-auth               1.35.0                   pypi_0    pypi
# google-auth-oauthlib      0.4.6                    pypi_0    pypi
# google-pasta              0.2.0                    pypi_0    pypi
# gql                       3.4.1                    pypi_0    pypi
# graphql-core              3.2.1                    pypi_0    pypi
# grpcio                    1.48.2                   pypi_0    pypi
# gym                       0.18.3                   pypi_0    pypi
# gym-notices               0.0.8                    pypi_0    pypi
# h5py                      3.1.0                    pypi_0    pypi
# idna                      3.4                      pypi_0    pypi
# importlib-metadata        4.8.3                    pypi_0    pypi
# importlib-resources       5.4.0                    pypi_0    pypi
# intel-openmp              2023.1.0         h59b6b97_46319
# joblib                    1.1.1                    pypi_0    pypi
# keras                     2.6.0                    pypi_0    pypi
# keras-applications        1.0.8                    pypi_0    pypi
# keras-preprocessing       1.1.2                    pypi_0    pypi
# kiwisolver                1.3.1                    pypi_0    pypi
# markdown                  3.3.7                    pypi_0    pypi
# matplotlib                3.3.4                    pypi_0    pypi
# mkl                       2020.2                      256
# mkl-service               2.3.0            py36h196d8e1_0
# mkl_fft                   1.3.0            py36h46781fe_0
# mkl_random                1.1.1            py36h47e9c7a_0
# multidict                 5.2.0                    pypi_0    pypi
# numpy                     1.19.5                   pypi_0    pypi
# numpy-base                1.19.2           py36ha3acd2a_0
# nvidia-ml-py3             7.352.0                  pypi_0    pypi
# oauthlib                  3.2.2                    pypi_0    pypi
# opt-einsum                3.3.0                    pypi_0    pypi
# packaging                 21.3                     pypi_0    pypi
# pandas                    1.1.5            py36hd77b12b_0
# pathtools                 0.1.2                    pypi_0    pypi
# pillow                    8.2.0                    pypi_0    pypi
# pip                       21.2.2           py36haa95532_0
# plotly                    5.15.0                   pypi_0    pypi
# progressbar2              3.55.0                   pypi_0    pypi
# promise                   2.3                      pypi_0    pypi
# protobuf                  3.19.6                   pypi_0    pypi
# psutil                    5.9.5                    pypi_0    pypi
# pyasn1                    0.5.0                    pypi_0    pypi
# pyasn1-modules            0.3.0                    pypi_0    pypi
# pybullet                  3.2.5                    pypi_0    pypi
# pyglet                    1.5.15                   pypi_0    pypi
# pyparsing                 3.1.0                    pypi_0    pypi
# python                    3.6.13               h3758d61_0
# python-dateutil           2.8.2              pyhd3eb1b0_0
# python-utils              3.5.2                    pypi_0    pypi
# pytz                      2021.3             pyhd3eb1b0_0
# pyyaml                    6.0.1                    pypi_0    pypi
# pyzmq                     25.1.0                   pypi_0    pypi
# requests                  2.27.1                   pypi_0    pypi
# requests-oauthlib         1.3.1                    pypi_0    pypi
# rsa                       4.9                      pypi_0    pypi
# scipy                     1.5.4                    pypi_0    pypi
# sentry-sdk                1.28.1                   pypi_0    pypi
# setproctitle              1.2.3                    pypi_0    pypi
# setuptools                58.0.4           py36haa95532_0
# shortuuid                 1.0.11                   pypi_0    pypi
# six                       1.15.0                   pypi_0    pypi
# smmap                     5.0.0                    pypi_0    pypi
# sqlite                    3.41.2               h2bbff1b_0
# subprocess32              3.5.4                    pypi_0    pypi
# tenacity                  8.2.2                    pypi_0    pypi
# tensorboard               1.14.0                   pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.1                    pypi_0    pypi
# tensorflow                1.14.0                   pypi_0    pypi
# tensorflow-determinism    0.3.0                    pypi_0    pypi
# tensorflow-estimator      1.14.0                   pypi_0    pypi
# tensorflow-gpu            1.14.0                   pypi_0    pypi
# tensorflow-probability    0.7.0                    pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# torch                     1.10.2                   pypi_0    pypi
# tqdm                      4.64.1                   pypi_0    pypi
# typing-extensions         3.7.4.3                  pypi_0    pypi
# urllib3                   1.26.16                  pypi_0    pypi
# vc                        14.2                 h21ff451_1
# vs2015_runtime            14.27.29016          h5e58377_2
# wandb                     0.13.2                   pypi_0    pypi
# watchdog                  2.3.1                    pypi_0    pypi
# werkzeug                  2.0.3                    pypi_0    pypi
# wheel                     0.37.1             pyhd3eb1b0_0
# wincertstore              0.2              py36h7fe50ca_0
# wrapt                     1.12.1                   pypi_0    pypi
# yarl                      1.7.2                    pypi_0    pypi
# zipp                      3.6.0                    pypi_0    pypi
# zmq                       0.0.0                    pypi_0    pypi
#
#
# # Name                    Version                   Build  Channel
# pytorch                   1.13.1          py3.7_cuda11.7_cudnn8_0    pytorch
# pytorch-cuda              11.7                 h67b0de4_1    pytorch
# pytorch-mutex             1.0                        cuda    pytorch
# torchaudio                0.13.1                   pypi_0    pypi
# torchvision               0.14.1                   pypi_0    pypi

# %% [markdown]
# 一些参数
# config = {
#     scope : bank1
#     state_dim : 48
#     action_dim : 2
#     action_bound : 0.5
#     REWARD_GAMMA : 0.95
#     MEMORY_CAPACITY : 80000
#     LEARNING_RATE_ACTOR : 0.001
#     LEARNING_RATE_CRITIC : 0.002
#     LEARNING_RATE_ACTOR_STABLE : 0.0001
#     LEARNING_RATE_CRITIC_STABLE : 0.0002
#     LEARNING_RATE_DECAY : 1
#     LEARNING_RATE_DECAY_TIME : 200
#     SOFT_REPLACE_TAU : 0.01
#     BATCH_SIZE : 3000
#     VAR_INIT : 0.5
#     VAR_STABLE : 0.001
#     VAR_DROP_AT : 3000
#     VAR_STABLE_AT : 80000
#     VAR_END_AT : 100000
#     SMOOTH_NOISE : 0.01
#     ACTOR_UPDATE_DELAY_TIMES : 3
#     IS_ACTOR_UPDATE_DELAY : True
#     IS_CRITIC_DOUBLE_NETWORK : True
#     IS_QNET_SMOOTH_CRITIC : True
#     random_seed : 184
# }
#
# state = dict{3} = {'produce1':list[],'consumpution1':list[],'bank1':list[]}
#     produce1 = [0.030420000000000003, 0.1885, 0.08237, 1.3539999999999999, 1.08, 0.9699543201189545, 1.3335748202807087, 0.1025647435045109, 0.00424, 0.0051600000000000005, 0.040999999999999995, 0.9508447974543042, 0.6534904563363354, 0.9699543201189545, 0.628, 1.2996900600450942, 0.43200000000000005, 0, 0, 0, 0, 0.9699543201189545, 0.726, 1.2996900600450942, 0.545, 0, 0, 0, 0, 1.3335748202807087, 10.0, 1.4171252308498594, 10.0]
#     consumpuion1 = [0.02619, 0.15005, 0.07364, 0.977, 1.3625, 1.2996900600450942, 1.4171252308498594, 0.0004441648280878449, 0.00015, 0.04625, 0.037, 0.9152392023835318, 0.6874604864190949, 0.9699543201189545, 0.628, 1.2996900600450942, 0.43200000000000005, 0, 0, 0, 0, 0.9699543201189545, 0.726, 1.2996900600450942, 0.545, 0, 0, 0, 0, 1.3335748202807087, 10.0, 1.4171252308498594, 10.0]
#     bank1 = [0.07400000000000001, 1.7823099999999998, 0.030420000000000003, 0.1885, 0.08237, 1.3539999999999999, 1.08, 0.9699543201189545, 1.3335748202807087, 0.1025647435045109, 0.00424, 0.0051600000000000005, 0.040999999999999995, 0.9508447974543042, 0.6534904563363354, 0.9699543201189545, 0.628, 1.2996900600450942, 0.43200000000000005, 0, 0, 0, 0, 0.9699543201189545, 0.726, 1.2996900600450942, 0.545, 0, 0, 0, 0, 1.3335748202807087, 10.0, 1.4171252308498594, 10.0, 0.02619, 0.15005, 0.07364, 0.977, 1.3625, 1.2996900600450942, 1.4171252308498594, 0.0004441648280878449, 0.00015, 0.04625, 0.037, 0.9152392023835318, 0.6874604864190949]
# action = dict{'produce1':nparray(4,),'consumpution1':nparray(4,),'bank1':nparray(2,)}
#     produce1 = [0.37445,0.21279,0.04689,0.10542] # 一行四列
#     bank1 = [0.62756,0.49785]
#
# reward = {dict:3}{'production1':{dict:2},'cunsumpution1':{dict:2},'bank1':{dict:1}}
#     priduction1 = {'economy':0(int),'bussiness':0(int)}
#     bank1 = {'WNDB':-10(int)}
#
# done = {bool} =True
#
# # packages in environment at C:\Users\lyk\.conda\envs\sevenpython36:
# #
# # Name                    Version                   Build  Channel
# absl-py                   0.15.0                   pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# astor                     0.8.1                    pypi_0    pypi
# astunparse                1.6.3                    pypi_0    pypi
# azure                     1.0.3                    pypi_0    pypi
# azure-common              1.1.28                   pypi_0    pypi
# azure-mgmt                0.20.2                   pypi_0    pypi
# azure-mgmt-common         0.20.0                   pypi_0    pypi
# azure-mgmt-compute        0.20.1                   pypi_0    pypi
# azure-mgmt-network        0.20.1                   pypi_0    pypi
# azure-mgmt-nspkg          3.0.2                    pypi_0    pypi
# azure-mgmt-resource       0.20.1                   pypi_0    pypi
# azure-mgmt-storage        0.20.0                   pypi_0    pypi
# azure-nspkg               3.0.2                    pypi_0    pypi
# azure-servicebus          0.20.1                   pypi_0    pypi
# azure-servicemanagement-legacy 0.20.2                   pypi_0    pypi
# azure-storage             0.20.3                   pypi_0    pypi
# backoff                   1.11.1                   pypi_0    pypi
# baselines                 0.1.3                    pypi_0    pypi
# blas                      1.0                         mkl
# cached-property           1.5.2                    pypi_0    pypi
# cachetools                4.2.4                    pypi_0    pypi
# certifi                   2021.5.30        py36haa95532_0
# charset-normalizer        2.0.12                   pypi_0    pypi
# clang                     5.0                      pypi_0    pypi
# click                     8.0.4                    pypi_0    pypi
# cloudpickle               1.6.0                    pypi_0    pypi
# colorama                  0.4.5                    pypi_0    pypi
# configparser              5.2.0                    pypi_0    pypi
# cycler                    0.11.0                   pypi_0    pypi
# dataclasses               0.8                      pypi_0    pypi
# decorator                 5.1.1                    pypi_0    pypi
# dill                      0.3.4                    pypi_0    pypi
# docker-pycreds            0.4.0                    pypi_0    pypi
# flatbuffers               1.12                     pypi_0    pypi
# gast                      0.4.0                    pypi_0    pypi
# gitdb                     4.0.9                    pypi_0    pypi
# gitpython                 3.1.18                   pypi_0    pypi
# google-auth               1.35.0                   pypi_0    pypi
# google-auth-oauthlib      0.4.6                    pypi_0    pypi
# google-pasta              0.2.0                    pypi_0    pypi
# gql                       3.4.1                    pypi_0    pypi
# graphql-core              3.2.1                    pypi_0    pypi
# grpcio                    1.48.2                   pypi_0    pypi
# gym                       0.18.3                   pypi_0    pypi
# gym-notices               0.0.8                    pypi_0    pypi
# h5py                      3.1.0                    pypi_0    pypi
# idna                      3.4                      pypi_0    pypi
# importlib-metadata        4.8.3                    pypi_0    pypi
# importlib-resources       5.4.0                    pypi_0    pypi
# intel-openmp              2023.1.0         h59b6b97_46319
# joblib                    1.1.1                    pypi_0    pypi
# keras                     2.6.0                    pypi_0    pypi
# keras-applications        1.0.8                    pypi_0    pypi
# keras-preprocessing       1.1.2                    pypi_0    pypi
# kiwisolver                1.3.1                    pypi_0    pypi
# markdown                  3.3.7                    pypi_0    pypi
# matplotlib                3.3.4                    pypi_0    pypi
# mkl                       2020.2                      256
# mkl-service               2.3.0            py36h196d8e1_0
# mkl_fft                   1.3.0            py36h46781fe_0
# mkl_random                1.1.1            py36h47e9c7a_0
# multidict                 5.2.0                    pypi_0    pypi
# numpy                     1.19.5                   pypi_0    pypi
# numpy-base                1.19.2           py36ha3acd2a_0
# nvidia-ml-py3             7.352.0                  pypi_0    pypi
# oauthlib                  3.2.2                    pypi_0    pypi
# opt-einsum                3.3.0                    pypi_0    pypi
# packaging                 21.3                     pypi_0    pypi
# pandas                    1.1.5            py36hd77b12b_0
# pathtools                 0.1.2                    pypi_0    pypi
# pillow                    8.2.0                    pypi_0    pypi
# pip                       21.2.2           py36haa95532_0
# plotly                    5.15.0                   pypi_0    pypi
# progressbar2              3.55.0                   pypi_0    pypi
# promise                   2.3                      pypi_0    pypi
# protobuf                  3.19.6                   pypi_0    pypi
# psutil                    5.9.5                    pypi_0    pypi
# pyasn1                    0.5.0                    pypi_0    pypi
# pyasn1-modules            0.3.0                    pypi_0    pypi
# pybullet                  3.2.5                    pypi_0    pypi
# pyglet                    1.5.15                   pypi_0    pypi
# pyparsing                 3.1.0                    pypi_0    pypi
# python                    3.6.13               h3758d61_0
# python-dateutil           2.8.2              pyhd3eb1b0_0
# python-utils              3.5.2                    pypi_0    pypi
# pytz                      2021.3             pyhd3eb1b0_0
# pyyaml                    6.0.1                    pypi_0    pypi
# pyzmq                     25.1.0                   pypi_0    pypi
# requests                  2.27.1                   pypi_0    pypi
# requests-oauthlib         1.3.1                    pypi_0    pypi
# rsa                       4.9                      pypi_0    pypi
# scipy                     1.5.4                    pypi_0    pypi
# sentry-sdk                1.28.1                   pypi_0    pypi
# setproctitle              1.2.3                    pypi_0    pypi
# setuptools                58.0.4           py36haa95532_0
# shortuuid                 1.0.11                   pypi_0    pypi
# six                       1.15.0                   pypi_0    pypi
# smmap                     5.0.0                    pypi_0    pypi
# sqlite                    3.41.2               h2bbff1b_0
# subprocess32              3.5.4                    pypi_0    pypi
# tenacity                  8.2.2                    pypi_0    pypi
# tensorboard               1.14.0                   pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.1                    pypi_0    pypi
# tensorflow                1.14.0                   pypi_0    pypi
# tensorflow-determinism    0.3.0                    pypi_0    pypi
# tensorflow-estimator      1.14.0                   pypi_0    pypi
# tensorflow-gpu            1.14.0                   pypi_0    pypi
# tensorflow-probability    0.7.0                    pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# torch                     1.10.2                   pypi_0    pypi
# tqdm                      4.64.1                   pypi_0    pypi
# typing-extensions         3.7.4.3                  pypi_0    pypi
# urllib3                   1.26.16                  pypi_0    pypi
# vc                        14.2                 h21ff451_1
# vs2015_runtime            14.27.29016          h5e58377_2
# wandb                     0.13.2                   pypi_0    pypi
# watchdog                  2.3.1                    pypi_0    pypi
# werkzeug                  2.0.3                    pypi_0    pypi
# wheel                     0.37.1             pyhd3eb1b0_0
# wincertstore              0.2              py36h7fe50ca_0
# wrapt                     1.12.1                   pypi_0    pypi
# yarl                      1.7.2                    pypi_0    pypi
# zipp                      3.6.0                    pypi_0    pypi
# zmq                       0.0.0                    pypi_0    pypi
